# %%
from sieve import main
import matplotlib.pyplot as plt
import numpy as np

# %%
nums = [21, 37 * 41, 4201 * 8011, 1000033 * 1000003, 100000007 * 10000169, 16921456439215439701, 
       100123456789 * 101103163367, 100000000105583 * 1000123465987, 1000000000100011 * 1084051191974761,
       10000000002065383 * 10112269203786181]
nums = [21, 37 * 41, 4201 * 8011, 1000033 * 1000003, 100000007 * 10000169, 16921456439215439701,
       100123456789 * 101103163367, 100000000105583 * 1000123465987]


epsilons = [0.1, 0.15]
smooth_time = []
elim_time = []
total_time = []



for num in nums:
    s, e, t = main(num)
    smooth_time.append(s)
    elim_time.append(e)
    total_time.append(t)
# Out:
# Bound: 4
# Finding smooth numbers ...
# Smooth Number 10:1
# Smooth Number 20:4
# Found smooth numbers
# Running Gaussian elimination ...
# piv row index 0
# Finding factors ...
# N = 7 * 3
# Bound: 11
# Finding smooth numbers ...
# Smooth Number 10:64
# Found smooth numbers
# Running Gaussian elimination ...
# piv row index 0
# Finding factors ...
# Trivial Factor
# Finding factors ...
# N = 37 * 41
# Bound: 70
# Finding smooth numbers ...
# Smooth Number 10:6427350
# Smooth Number 20:35972
# Smooth Number 30:10875000
# Found smooth numbers
# Running Gaussian elimination ...
# piv row index 0
# Finding factors ...
# Trivial Factor
# Finding factors ...
# Trivial Factor
# Finding factors ...
# Trivial Factor
# Finding factors ...
# Trivial Factor
# Finding factors ...
# Trivial Factor
# Finding factors ...
# N = 8011 * 4201
# Bound: 316
# Finding smooth numbers ...
# Smooth Number 10:666123102
# Smooth Number 20:4054173750
# Smooth Number 30:9372024150
# Smooth Number 40:16991876385
# Smooth Number 50:24780078125
# Found smooth numbers
# Running Gaussian elimination ...
# piv row index 0
# Finding factors ...
# Trivial Factor
# Finding factors ...
# Trivial Factor
# Finding factors ...
# Trivial Factor
# Finding factors ...
# Trivial Factor
# Finding factors ...
# N = 1000003 * 1000033
# Bound: 777
# Finding smooth numbers ...
# Smooth Number 10:206134699233
# Smooth Number 20:555382829442
# Smooth Number 30:1001631097701
# Smooth Number 40:1541716296561
# Smooth Number 50:2303487706842
# Smooth Number 60:3363092629442
# Smooth Number 70:3785000270373
# Smooth Number 80:4871698599258
# Found smooth numbers
# Running Gaussian elimination ...
# piv row index 0
# Finding factors ...
# N = 10000169 * 100000007
# Bound: 2385
# Finding smooth numbers ...
# Smooth Number 10:12968641094460
# Smooth Number 20:38645563320399
# Smooth Number 30:58686904169775
# Smooth Number 40:106017753377340
# Smooth Number 50:118975541296815
# Smooth Number 60:163484552193195
# Smooth Number 70:232922016955115
# Smooth Number 80:272297400912399
# Smooth Number 90:340805412781388
# Smooth Number 100:427898901531108
# Smooth Number 110:477056717777583
# Smooth Number 120:513774979242380
# Smooth Number 130:584134618229148
# Smooth Number 140:639940315236075
# Smooth Number 150:760190674805163
# Smooth Number 160:818761047775020
# Smooth Number 170:902095863273899
# Smooth Number 180:947305230514524
# Smooth Number 190:1014399498308399
# Smooth Number 200:1071324831160380
# Found smooth numbers
# Running Gaussian elimination ...
# piv row index 0
# piv row index 100
# Finding factors ...
# N = 2860486313 * 5915587277

# %%
fig, axs_all = plt.subplots(1, 2)
fig.set_size_inches(8, 4)
fig.tight_layout(pad=3)
axs = axs_all[0]
total_time_s = [total_time[i] / 1000 for i in range(len(total_time))]
elim_time_s = [elim_time[i] / 1000 for i in range(len(elim_time))]
smooth_time_s = [smooth_time[i] / 1000 for i in range(len(smooth_time))]
log_nums = np.log10([float(nums[i]) for i in range(len(nums))])
up_to = len(nums)
axs.scatter(log_nums[:up_to], total_time_s[:up_to])
axs.plot(log_nums[:up_to], total_time_s[:up_to])

axs.scatter
axs.set_xlabel("Log_10(n)")
axs.set_ylabel("Time (s) to Factor n")
axs.set_title("Time (s) to Factor n")

axs = axs_all[1]
start = 3
ratio_e = [elim_time_s[i] / total_time_s[i] for i in range(start, len(smooth_time_s))]
ratio_s = [smooth_time_s[i] / total_time_s[i] for i in range(start, len(smooth_time_s))]
axs.scatter(log_nums[start:], ratio_s)
axs.scatter(log_nums[start:], ratio_e)
axs.plot(log_nums[start:], ratio_s)
axs.plot(log_nums[start:], ratio_e)
axs.set_xlabel("Log_10(n)")
axs.set_ylabel("Ratio to Total Time Spent")
axs.legend(['Finding Smooth Numbers', "Gaussian Elimination" ])
axs.set_title("Time Spent on Gaussian Elimination\n and on Finding Smooth Numbers")
# Out:
# Text(0.5, 1.0, 'Time Spent on Gaussian Elimination\n and on Finding Smooth Numbers')

# %%
fig, axs = plt.subplots()
start = 3
ratio_e = [elim_time_s[i] / total_time_s[i] for i in range(start, len(smooth_time_s))]
ratio_s = [smooth_time_s[i] / total_time_s[i] for i in range(start, len(smooth_time_s))]
axs.scatter(log_nums[start:], ratio_s)
axs.scatter(log_nums[start:], ratio_e)
axs.plot(log_nums[start:], ratio_s)
axs.plot(log_nums[start:], ratio_e)
axs.set_xlabel("Log_10(n)")
axs.set_ylabel("Ratio to Total Time Spent")
axs.legend(['Finding Smooth Numbers', "Gaussian Elimination" ])
axs.set_title("Time Spent on Gaussian Elimination and on Finding Smooth Numbers")
# Out:
# Text(0.5, 1.0, 'Time Spent on Gaussian Elimination and on Finding Smooth Numbers')

# %%
nums
# Out:
# [21,
#  1517,
#  33654211,
#  1000036000099,
#  1000016970001183,
#  16921456439215439701,
#  10122798208607032248563,
#  100012346704296035909305421,
#  1084051192083178043760587822371,
#  101122692058747518904923513872323]

# %%
elim_time
# Out:
# [0, 2, 0, 0, 0, 0]

# %%
def power(a, n, p):
    ret = 1
    while n > 0:
        if n % 2 == 1:
            ret = (ret * a) % p
        a = (a * a) % p
        n //= 2
    return ret

# %%
import random
random.randint(0, 12)
# Out:
# 10

# %%
def check_prime(n, iter=10):
    #run Miller rabin several times with different values of a
    if (pow(2, n-1, n) != 1):
        return False
    m = 1
    beta = n -1
    k = 0
    while (beta % 2 == 0):
        beta = beta >> 1
        k += 1
    m = (n-1) >> k 
    for i in range(iter):
        a = random.randint(2, n-2)
        b_0 = power(a, m, n)
        if (b_0 == 1) or (b_0 == -1) or (b_0 == n-1):
            #n is probably prime
            continue
        b_j = b_0
        j = 1
        while (j) < k:
            b_j = (b_j * b_j) % n
            if (b_j == 1):
                return False
            elif (b_j == -1) or (b_j == n-1):
                #n is probably prime
                break
            j += 1
    return True

# %%
[1, 2, 3] + [5, 12, 2]
# Out:
# [1, 2, 3, 5, 12, 2]

# %%
m = [[1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]]
r = m[1]
r = [5, 3, 2]
m
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
[i for i in r if i % 2 == 0]
# Out:
# [2]
